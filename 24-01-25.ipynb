# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("annual_enterprise.csv")
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 50980                          Quick ratio  Financial ratios    52
# 50981  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
m = df['Industry_aggregation_NZSIOC']
m
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 50980    Level 3
# 50981    Level 3
# 50982    Level 3
# 50983    Level 3
# 50984    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 50985, dtype: object

# %%
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.iloc[2:]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# 5      2023                     Level 1                99999
# 6      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
df.iloc[2:,2:-3]
# Out:
#       Industry_code_NZSIOC        Industry_name_NZSIOC               Units  \
# 2                    99999              All industries  Dollars (millions)
# 3                    99999              All industries  Dollars (millions)
# 4                    99999              All industries  Dollars (millions)
# 5                    99999              All industries  Dollars (millions)
# 6                    99999              All industries  Dollars (millions)
# ...                    ...                         ...                 ...
# 50980                 ZZ11  Food product manufacturing          Percentage
# 50981                 ZZ11  Food product manufacturing          Percentage
# 50982                 ZZ11  Food product manufacturing          Percentage
# 50983                 ZZ11  Food product manufacturing          Percentage
# 50984                 ZZ11  Food product manufacturing          Percentage
#
#       Variable_code                        Variable_name
# ...

# %%
l = df['Industry_code_ANZSIC06'].nunique
l
# Out:
# <bound method IndexOpsMixin.nunique of 0        ANZSIC06 divisions A-S (excluding classes K633...
# 1        ANZSIC06 divisions A-S (excluding classes K633...
# 2        ANZSIC06 divisions A-S (excluding classes K633...
# 3        ANZSIC06 divisions A-S (excluding classes K633...
# 4        ANZSIC06 divisions A-S (excluding classes K633...
#                                ...
# 50980    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50982    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50983    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50984    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# Name: Industry_code_ANZSIC06, Length: 50985, dtype: object>

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 50980    False
# 50981    False
# 50982    False
# 50983    False
# 50984    False
# Length: 50985, dtype: bool

# %%
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df = df.rename(columns = {'Industry_name_NZSIOC':'Nzsioc'})

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC          Nzsioc  \
# 0  2023                     Level 1                99999  All industries
# 1  2023                     Level 1                99999  All industries
# 2  2023                     Level 1                99999  All industries
# 3  2023                     Level 1                99999  All industries
# 4  2023                     Level 1                99999  All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
# ...

# %%
c  = df['Industry_aggregation_NZSIOC'].max()
c
# Out:
# 'Level 4'

# %%
df1 = pd.read_csv('Virat-Kohli-International-Cricket-Centuries.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       80 non-null     int64
#  1   Runs      80 non-null     object
#  2   Against   80 non-null     object
#  3   Position  80 non-null     int64
#  4   Innings   80 non-null     int64
#  5   Venue     80 non-null     object
#  6   Ground    79 non-null     object
#  7   Date      80 non-null     object
#  8   Result    80 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 5.8+ KB

# %%
k = df1['No.'].mean()
k
# Out:
# 40.5

# %%
r = df1['No.'].median()
r
# Out:
# 40.5

# %%
df1.select_dtypes(include=['number']).corr()
# Out:
#                No.  Position   Innings
# No.       1.000000 -0.274009 -0.182706
# Position -0.274009  1.000000  0.287634
# Innings  -0.182706  0.287634  1.000000

# %%
df1.isnull().sum()
# Out:
# No.         0
# Runs        0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      1
# Date        0
# Result      0
# dtype: int64

# %%
df1.fillna('unknown')
# Out:
#     No.   Runs       Against  Position  Innings  \
# 0     1    107     Sri Lanka         4        2
# 1     2  102*     Bangladesh         3        2
# 2     3    118     Australia         3        2
# 3     4    105   New Zealand         3        1
# 4     5   100*    Bangladesh         4        1
# ..  ...    ...           ...       ...      ...
# 75   76    121   West Indies         4        1
# 76   77   122*      Pakistan         3        1
# 77   78   103*    Bangladesh         3        2
# 78   79   101*  South Africa         3        1
# 79   80    117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 0                           Eden Gardens, Kolkata     Home  24-Dec-09    Won
# 1            Sher-e-Bangla Cricket Stadium, Dhaka     Away  11-Jan-10    Won
# 2                APCA-VDCA Stadium, Visakhapatnam     Home  20-Oct-10    Won
# 3                         Nehru Stadium, Guwahati     Home  28-Nov-10    Won
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50985, step=1)

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([[2023, 'Level 1', '99999', ..., 'Financial performance', '930995',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2023, 'Level 1', '99999', ..., 'Financial performance', '821630',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2023, 'Level 1', '99999', ..., 'Financial performance', '84354',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        ...,
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '12',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '5',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '46',
# ...

# %%
m1 = df.T
m1
# Out:
#                                                                          0      \
# Year                                                                      2023
# Industry_aggregation_NZSIOC                                            Level 1
# Industry_code_NZSIOC                                                     99999
# Industry_name_NZSIOC                                            All industries
# Units                                                       Dollars (millions)
# Variable_code                                                              H01
# Variable_name                                                     Total income
# Variable_category                                        Financial performance
# Value                                                                   930995
# Industry_code_ANZSIC06       ANZSIC06 divisions A-S (excluding classes K633...
#
#                                                                          1      \
# ...

# %%
df.sort_index(axis=1)
# Out:
#       Industry_aggregation_NZSIOC  \
# 0                         Level 1
# 1                         Level 1
# 2                         Level 1
# 3                         Level 1
# 4                         Level 1
# ...                           ...
# 50980                     Level 3
# 50981                     Level 3
# 50982                     Level 3
# 50983                     Level 3
# 50984                     Level 3
#
#                                   Industry_code_ANZSIC06 Industry_code_NZSIOC  \
# 0      ANZSIC06 divisions A-S (excluding classes K633...                99999
# 1      ANZSIC06 divisions A-S (excluding classes K633...                99999
# 2      ANZSIC06 divisions A-S (excluding classes K633...                99999
# 3      ANZSIC06 divisions A-S (excluding classes K633...                99999
# 4      ANZSIC06 divisions A-S (excluding classes K633...                99999
# ...                                                  ...                  ...
# ...

# %%
df.sort_values("Value")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27424  2018                     Level 4                QQ111
# 47238  2013                     Level 4                CC411
# 47202  2013                     Level 3                 CC41
# 3270   2023                     Level 4                KK121
# 32685  2016                     Level 4                AA131
# ...     ...                         ...                  ...
# 49887  2013                     Level 4                LL122
# 31347  2017                     Level 4                LL122
# 40219  2015                     Level 3                 KK11
# 40221  2015                     Level 3                 KK11
# 40618  2015                     Level 4                LL122
#
#                      Industry_name_NZSIOC               Units Variable_code  \
# 27424                           Hospitals          Percentage           H40
# 47238                            Printing          Percentage           H40
# ...
